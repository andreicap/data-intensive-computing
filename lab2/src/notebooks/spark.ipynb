// %% [markdown]
// # Lab 2 - Spark
// This lab will demonstrate how to perform web server log analysis with Spark. Log data is a very large, common data source and contains a rich set of information.  It comes from many sources, such as web, file, and compute servers, application logs, user-generated content,  and can be used for monitoring servers, improving business and customer intelligence, building recommendation systems, fraud detection, and much more. This lab will show you how to use Spark on real-world text-based production logs and fully harness the power of that data.
//
// ### Apache Web Server Log file format
// The log files that we use for this assignment are in the [Apache Common Log Format (CLF)](http://httpd.apache.org/docs/1.3/logs.html#common) format. The log file entries produced in CLF will look something like this:
// `127.0.0.1 - - [01/Aug/1995:00:00:01 -0400] "GET /images/launch-logo.gif HTTP/1.0" 200 1839`
//
// Each part of this log entry is described below.
// * **`127.0.0.1`:** this is the IP address (or host name, if available) of the client (remote host) which made the request to the server.
// * **`-`:** the "hyphen" in the output indicates that the requested piece of information (user identity from remote machine) is not available.
// * **`-`:** the "hyphen" in the output indicates that the requested piece of information (user identity from local logon) is not available.
// * **`[01/Aug/1995:00:00:01 -0400]`:** the time that the server finished processing the request. The format is:
// `[day/month/year:hour:minute:second timezone]`.
// * **`"GET /images/launch-logo.gif HTTP/1.0"`:** this is the first line of the request string from the client. It consists of a three components: the request method (e.g., `GET`, `POST`, etc.), the endpoint, and the client protocol version.
// * **`200`:** this is the status code that the server sends back to the client. This information is very valuable, because it reveals whether the request resulted in a successful response (codes beginning in 2), a redirection (codes beginning in 3), an error caused by the client (codes beginning in 4), or an error in the server (codes beginning in 5). The full list of possible status codes can be found in the HTTP specification ([RFC 2616](https://www.ietf.org/rfc/rfc2616.txt) section 10).
// * **`1839`:** the last entry indicates the size of the object returned to the client, not including the response headers. If no content was returned to the client, this value will be "-" (or sometimes 0).
//
// Using the CLF as defined above, we create a regular expression pattern to extract the nine fields of the log line. The function returns a pair consisting of a Row object and 1. If the log line fails to match the regular expression, the function returns a pair consisting of the log line string and 0. A '-' value in the content size field is cleaned up by substituting it with 0. The function converts the log line's date string into a `Cal` object using the given `parseApacheTime` function. We, then, create the primary RDD and  we'll use in the rest of this assignment. We first load the text file and convert each line of the file into an element in an RDD. Next, we use `map(parseApacheLogLine)` to apply the parse function to each element and turn each line into a pair `Row` object. Finally, we cache the RDD in memory since we'll use it throughout this notebook. The log file is available at `data/apache/apache.log`.

// %%
import scala.util.matching
import org.apache.spark.rdd.RDD

case class Cal(year: Int, month: Int, day: Int, hour: Int, minute: Int, second: Int)                

case class Row(host: String, clientID: String, userID: String, dateTime: Cal, method: String, endpoint: String,
               protocol: String, responseCode: Int, contentSize: Long)                

val month_map = Map("Jan" -> 1, "Feb" -> 2, "Mar" -> 3, "Apr" -> 4, "May" -> 5, "Jun" -> 6, "Jul" -> 7, "Aug" -> 8,
                    "Sep" -> 9, "Oct" -> 10, "Nov" -> 11, "Dec" -> 12)

//------------------------------------------------
// A regular expression pattern to extract fields from the log line
val APACHE_ACCESS_LOG_PATTERN = """^(\S+) (\S+) (\S+) \[([\w:/]+\s[+\-]\d{4})\] "(\S+) (\S+)\s*(\S*)\s*" (\d{3}) (\S+)""".r

//------------------------------------------------
def parseApacheTime(s: String): Cal = {
    return Cal(s.substring(7, 11).toInt, month_map(s.substring(3, 6)), s.substring(0, 2).toInt, 
               s.substring(12, 14).toInt, s.substring(15, 17).toInt, s.substring(18, 20).toInt)
}

//------------------------------------------------
def parseApacheLogLine(logline: String): (Either[Row, String], Int) = {
    val ret = APACHE_ACCESS_LOG_PATTERN.findAllIn(logline).matchData.toList
    if (ret.isEmpty)
        return (Right(logline), 0)

    val r = ret(0)
    val sizeField = r.group(9)

    var size: Long = 0
    if (sizeField != "-")
        size = sizeField.toLong

    return (Left(Row(r.group(1), r.group(2), r.group(3), parseApacheTime(r.group(4)), r.group(5), r.group(6),
                     r.group(7), r.group(8).toInt, size)), 1)
}

//------------------------------------------------
def parseLogs(): (RDD[(Either[Row, String], Int)], RDD[Row], RDD[String]) = {
    val fileName = "file:/Users/andreicapastru/Desktop/Data Intensive Computing/data-intensive-computing/lab2/src/notebooks/data/apache/apache.log"
    
    val parsedLogs = sc.textFile(fileName).map(parseApacheLogLine).cache()
    val accessLogs = parsedLogs.filter(x => x._2 == 1).map(x => x._1.left.get)
    val failedLogs = parsedLogs.filter(x => x._2 == 0).map(x => x._1.right.get)

    val failedLogsCount = failedLogs.count()
    
    if (failedLogsCount > 0) {
        println(s"Number of invalid logline: $failedLogs.count()")
        failedLogs.take(20).foreach(println)
    }
    
    println(s"Read $parsedLogs.count() lines, successfully parsed $accessLogs.count() lines, and failed to parse $failedLogs.count()")
    
    return (parsedLogs, accessLogs, failedLogs)
}
// Out:
// defined class Cal
// defined class Row
// month_map = Map(Nov -> 11, Jul -> 7, Mar -> 3, Jan -> 1, Oct -> 10, Dec -> 12, Feb -> 2, May -> 5, Apr -> 4, Aug -> 8, Sep -> 9, Jun -> 6)
// APACHE_ACCESS_LOG_PATTERN = ^(\S+) (\S+) (\S+) \[([\w:/]+\s[+\-]\d{4})\] "(\S+) (\S+)\s*(\S*)\s*" (\d{3}) (\S+)
// parseApacheTime: (s: String)Cal
// parseApacheLogLine: (logline: String)(Either[Row,String], Int)
// parseLogs: ()(org.apache.spark.rdd.RDD[(Either[Row,String], Int)], org.apache.spark.rdd.RDD[Row], org.apache.spark.rdd.RDD[String])
// ^(\S+) (\S+) (\S+) \[([\w:/]+\s[+\-]\d{4})\] "(\S+) (\S+)\s*(\S*)\s*" (\d{3}) (\S+)

// %%
val (parsedLogs, accessLogs, failedLogs) = parseLogs()
// Out:
// Read MapPartitionsRDD[2] at map at <console>:66.count() lines, successfully parsed MapPartitionsRDD[4] at map at <console>:67.count() lines, and failed to parse MapPartitionsRDD[6] at map at <console>:68.count()
// parsedLogs = MapPartitionsRDD[2] at map at <console>:66
// accessLogs = MapPartitionsRDD[4] at map at <console>:67
// failedLogs = MapPartitionsRDD[6] at map at <console>:68
// MapPartitionsRDD[6] at map at <console>:68
// (/pub/winvn/readme.txt,1)
// (/shuttle/technology/images/sts-comm-small.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/history/apollo/sa-1/docs/,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/pub/winvn/release.txt,1)
// (/elv/new01.gif>,1)
// (/pub/winvn/readme.txt,1)
// (/elv/DELTA/uncons.htm,1)
// (/pub/winvn/release.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/robots.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/shuttle/missionssts-70/woodpecker.html,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo-13/apollo-13info.html,1)
// (/images/lf-logo.gif,1)
// (/history/apollo-13/apollo-13i-nfo.html,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/history/apollo/apollo-13/apollo-13info.html,1)
// (/pub/winvn/release.txt,1)
// (/robots.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/images/spaceport-logo.gif,1)
// (/history.html,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/~mccoy/ASYLUM/index.html,1)
// (/de/systems.html,1)
// (/~mccoy/,1)
// (/home.html,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/elv/DELTA/uncons.htm,1)
// (/elv/DELTA/uncons.htm,1)
// (/history/apollo/apollo-13info.html,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/resources/orbiters/columbia.html,1)
// (/pub/winvn/readme.txt,1)
// (/history.html,1)
// (/elv/DELTA/uncons.htm,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/ksc.hmtl,1)
// (/pub/winvn/readme.txt,1)
// (/ksc.hmtl,1)
// (/history/ftp.spies.com,1)
// (/images/crawlerway-logo.gif,1)
// (/ksc.html.,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/history/apollo/pad-abort-test-1/images/,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/pad-abort-test-1/sounds/,1)
// (/shuttle/news/sci.space.news/50,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/statistics/Feb.wwwstats.html,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/techonology/sts-newsref/stsref-toc.html,1)
// (/pub/winvn/readme.txt,1)
// (/technology/,1)
// (/history/apollo/a-003/a-003-patch-small.gif,1)
// (/history/apollo/a-003/news/,1)
// (/robots.txt,1)
// (/history/apollo/a-003/a-003-patch-small.gif,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/apod/lib/glossary.html,1)
// (/pub/winvn/release.txt,1)
// (/apod/lib/edlinks.html,1)
// (/www/software/winvn/winvn.html,1)
// (/apod/archivepix.html,1)
// (/history/history.htm,1)
// (/apod/archivepix.html,1)
// (/elv/DELTA/uncons.htm,1)
// (/apod/archivepix.html,1)
// (/sts-71/launch/,1)
// (/apod/archivepix.html,1)
// (/history/apollo/apollo-13.html,1)
// (/images/nav.gif,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/apod/astropix.html,1)
// (/history/apollo/a-001/movies/,1)
// (/apod/astropix.html,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/images/new.gif,1)
// (/history/apollo/a-001/movies/,1)
// (/images/rating.gif,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/apod/astropix.html,1)
// (/history/apollo/a-001/images/,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/a-004/a-004-patch-small.gif,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/history/apollo/a-004/movies/,1)
// (/software/winvn/winvn.html.,1)
// (/history/apollo/a-004/a-004-patch-small.gif,1)
// (/pub/win3,1)
// (/pub/winvn/release.txt,1)
// (/pub/,1)
// (/pub/winvn/readme.txt,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/Government/Research_Labs/NASA/,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/shuttle/missions/technology/sts-newsref/stsref-toc.html,1)
// (/pub/winvn/readme.txt,1)
// (/images/lf-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/history/appollo,1)
// (/pub/winvn/release.txt,1)
// (/history/appollo,1)
// (/ksc.htm1,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/ksc.htm1,1)
// (/NASA_homepage.html,1)
// (/history/apollo/html,1)
// (/software/winvn/winvn,1)
// (/pub/winvn/readme.txt,1)
// (/software/winvn/winvn.,1)
// (/pub/winvn/release.txt,1)
// (/.../liftoff.html,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/Nasa-logo.gif,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/Nasa-logo.gif,1)
// (/images/crawlerway-logo.gif,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/coutdown/,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/Nasa-logo.gif,1)
// (/de/systems.html,1)
// (/images/Nasa-logo.gif,1)
// (/KSC.html,1)
// (/images/Nasa-logo.gif,1)
// (/asdf,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/ksclogo.gif,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/images/Nasa-logo.gif,1)
// (/medlink/,1)
// (/images/Nasa-logo.gif,1)
// (/icons/im,1)
// (/images/Nasa-logo.gif,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/images/Nasa-logo.gif,1)
// (/payloads/systems.html,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/asdf,1)
// (/images/Nasa-logo.gif,1)
// (/Shuttle/missions/STS-69/images/images.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/images/images.html,1)
// (/images/Nasa-logo.gif,1)
// (/Shuttle/missions/sts-69/images/image.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/sts-69/images/images/html,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/icons/image.xb,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/software/winvn.html,1)
// (/images/Nasa-logo.gif,1)
// (/software/winvn.html,1)
// (/images/Nasa-logo.gif,1)
// (/software/winvn.html/,1)
// (/images/Nasa-logo.gif,1)
// (/hmhome.hm.l,1)
// (/images/Nasa-logo.gif,1)
// (/history/apollo/apollo-13/apollo-13.html.,1)
// (/images/Nasa-logo.gif,1)
// (/software/winvn.html/,1)
// (/images/Nasa-logo.gif,1)
// (/software/winvn.html,1)
// (/images/Nasa-logo.gif,1)
// (/history/apollo/apollo-13/apollo-13.html.,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/Nasa-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/sts-71/video/landing.gif,1)
// (/images/Nasa-logo.gif,1)
// (/images/crawlerway-logo.gif,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/sts-69/images/images.ht,1)
// (/images/Nasa-logo.gif,1)
// (/history/apollo/sa-3/sa-3-patch-small.gif,1)
// (/images/Nasa-logo.gif,1)
// (/history/apollo/sa-3/movies/,1)
// (/images/Nasa-logo.gif,1)
// (/history/apollo/sa-3/images/,1)
// (/elv/DELTA/uncons.htm,1)
// (/pub/winvn/release.txt,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/images/Nasa-logo.gif,1)
// (/elv/new01.gif>,1)
// (/images/Nasa-logo.gif,1)
// (/elv/new01.gif>,1)
// (/images/Nasa-logo.gif,1)
// (/i,1)
// (/images/Nasa-logo.gif,1)
// (/i,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/Nasa-logo.gif,1)
// (/shuttle/missions/sts-71/count.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/shuttle/missions/sts-71/count71.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/history/apollo/sa-5/sa-5-patch-small.gif,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/history/apollo/sa-5/movies/,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/sa-5/sounds/,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/sa-5/sa-5-patch-small.gif,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/shuttle/missions/sts-86/mission-sts-86.html,1)
// (/APOLLO-13,1)
// (/images/crawlerway-logo.gif,1)
// (/APOLLO-13.HTML,1)
// (/images/crawlerway-logo.gif,1)
// (/HISTORY,1)
// (/pub/winvn/readme.txt,1)
// (/HISTORY/APOLLO/APOLLO-13/APOLLO-13.HTML,1)
// (/pub/winvn/release.txt,1)
// (/robots.txt,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/pub/winvn/readme.txt,1)
// (/software/winvn/winvn.html.,1)
// (/pub/winvn/release.txt,1)
// (/software/winvn/winvn.html.,1)
// (/shuttle/technology/sts-newsref/spacelab,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/HISTORY/APOLLO,1)
// (/de/systems.html,1)
// (/HISTORY/APOLLO/APOLLO-13/APOLLO-13.HTML,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/missions/sts-70/liftoff.html,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/missions/sts-70/liftoff.html,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/countdown/aa.html,1)
// (/images/lf-logo.gif,1)
// (/pub/winvn,1)
// (/persons/astronauts/q-to-t/TrulyRH.txt,1)
// (/pub/winvn/,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/pub/,1)
// (/history/apollo/sa-1/movies/,1)
// (/pub,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/shuttle/countdown/ab.html,1)
// (/shuttle/technology/sts-news,1)
// (/shuttle/countdown/ac.html,1)
// (/elv/DELTA/uncons.htm,1)
// (/shuttle/missions/sts-69/video/livevideo2.gif,1)
// (/history/apollo/apollo-13-info.html,1)
// (/history/apollo/sa-2/sa-2-patch-small.gif,1)
// (/elv/DELTA/uncons.htm,1)
// (/history/apollo/sa-2/sa-2-patch-small.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/tecnology/stsreftoc.html,1)
// (/shuttle/missions/sts-87/mission-sts-87.html,1)
// (/shuttle/mission,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-71/video/landing.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/missions/sts-71/video/landing.gif,1)
// (/history/apollo/a-001/docs/,1)
// (/elv/DELTA/uncons.htm,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-61a/mission-sts-61a.html,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/elv/DELTA/uncons.htm,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/SDG/Experimental/demoweb/return.gif,1)
// (/statistics/Mar.wwwstats.html,1)
// (/fastronaut.htm,1)
// (/HOME.AOL.COM/GLCF%20PAT,1)
// (/astronaut.*,1)
// (/facilities/tour.html-OLD,1)
// (/fastronaut.*,1)
// (/shuttle/technology/images/sts-cron-72-small.gif,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/elv/DELTA/uncons.htm,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/astronaut.htm,1)
// (/pub/winvn/release.txt,1)
// (/it-www.hq.nasa.gov/EmailWhitePaper.html,1)
// (/pub/winvn/readme.txt,1)
// (/history/saturn,1)
// (/pub/winvn/readme.txt,1)
// (/images/vab-medium.gif:,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-71/images/image.html,1)
// (/PTS/thin_strip2.gif,1)
// (/history/saturn,1)
// (/pub/winvn/nt,1)
// (/shuttle/missions/sts-71/images/image.html,1)
// (/pub/winvn/nt,1)
// (/images/vab-medium.gif:,1)
// (/PTS/thin_strip2.gif,1)
// (/pub/winvn/readme.txt,1)
// (/warning.gif,1)
// (/elv/DELTA/uncons.htm,1)
// (/SDG/Experimental/demoweb/return.gif,1)
// (/SDG/Experimental/demoweb/return.gif,1)
// (/shuttle/countdown/count69.gif,1)
// (/shuttle/missions/sts-79/mission-sts-79.html,1)
// (/shuttle/countdown/count69.gif,1)
// (/astronaut.*,1)
// (/shuttle/countdown/count69.gif,1)
// (/shuttle/countdown/video/livevideo.jpeg,1)
// (/shuttle/countdown/count69.gif,1)
// (/images/crawlerway-logo.gif,1)
// (/shuttle/countdown/count69.gif,1)
// (/images/crawlerway-logo.gif,1)
// (/shuttle/countdown/count69.gif,1)
// (/images/crawlerway-logo.gif,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub/winvn/release.txt,1)
// (/search-page.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/technology/stsnewsrof/stsref-toc.html,1)
// (/software/winvn/winvn.html.,1)
// (/www/,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/www/ksc,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/lf-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/countdown/count69.gif,1)
// (/sales@summagraphics.com,1)
// (/shuttle/countdown/count69.gif,1)
// (/sales@summagraphics.com.,1)
// (/shuttle/countdown/count69.gif,1)
// (/sales@summagraphics.com,1)
// (/shuttle/countdown/count69.gif,1)
// (/sales@summagraphics.com,1)
// (/shuttle/countdown/count69.gif,1)
// (/sales@summagraphics.com,1)
// (/shuttle/countdown/count69.gif,1)
// (/sales@summagraphics.com.,1)
// (/shuttle/countdown/count69.gif,1)
// (/sales@summagraphics.com,1)
// (/shuttle/countdown/count69.gif,1)
// (/shuttle/missions/sts-63/sts-63-press-kit.tx,1)
// (/shuttle/countdown/count69.gif,1)
// (/news/sci.space.shuttle/archive/sci-space-shuttle-22-dec-1994-06.txt,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/countdown/count69.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/countdown/count69.gif,1)
// (/shuttle/technology/sts-newsref/stsref-to.html,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-79/mission-sts-79.html,1)
// (/shuttle/countdown/count69.gif,1)
// (/shuttle/missions/sts-81/mission-sts-81.html,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/countdown/count69.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/unitedmedia.com/comics/dilbert,1)
// (/pub/win3/winvn.,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/countdown/count69.gif,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/shuttle/countdown/count69.gif,1)
// (/robots.txt,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/sa-10/sa-10-patch-small.gif,1)
// (/shuttle/countdown/count69.gif,1)
// (/history/apollo/sa-10/images/,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/sa-10/sa-10-patch-small.gif,1)
// (/images/crawlerway-logo.gif,1)
// (/htbin/wais.pl%3FUSMP-2,1)
// (/images/lf-logo.gif,1)
// (/shuttle/technology/sts-newsref/sts-jsc.html',1)
// (/images/lf-logo.gif,1)
// (/shuttle/technology/sts-newsref/sts-jsc.html',1)
// (/images/lf.gif,1)
// (/shuttle/technology/sts-newsref/sts-jsc.html',1)
// (/images/lf.gif,1)
// (/shuttle/technology/sts-newsref/sts-jsc.html',1)
// (/pub/win3/winvn,1)
// (/shuttle/technology/sts-newsref/sts-jsc.html',1)
// (/pub/win3,1)
// (/pub/winvn/readme.txt,1)
// (/pub/,1)
// (/htbin/wais.pl%3FUSMP-2,1)
// (/pub,1)
// (/htbin/wais.pl%3FUSMP,1)
// (/history.html,1)
// (/history/apollo/apollo-13/appollo-13.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/procurement/business/ciao1.htm,1)
// (/shuttle/countdown/count69.gif,1)
// (/hutchnet.html,1)
// (/pub/winvn/release.txt,1)
// (/http:eryx.syr.edu,1)
// (/pub/winvn/readme.txt,1)
// (/images/lf-logo.gif,1)
// (/elv/DELTA/uncons.htm,1)
// (/ksc.hmtl,1)
// (/software/winvn/winvn.html.,1)
// (/ksc.hmtl,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/shuttle/missions/sts-80/mission-sts-80.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-80/mission-sts-80.html,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-79/mission-sts-79.html,1)
// (/history/appollo/apollo13/-apollo-13-info.html,1)
// (/shuttle/missions/sts-80/mission-sts-80.html,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/pub/winvn/release.txt,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-71/movies/l,1)
// (/elv/DELTA/uncons.htm,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/elv/DELTA/uncons.htm,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/statistics/1995/Jul/Jul95_request.gif,1)
// (/shuttle/technology/sts-newsref/stsref-toc%3Ahtml,1)
// (/statistics/1995/Jul/Jul95_byte.gif,1)
// (/shuttle/mission/mission.html,1)
// (/statistics/1995/Jul/Jul95_request.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/statistics/1995/Jul/Jul95_byte.gif,1)
// (/news/sci.space.shuttle/archive/sci-space-shuttle-28-jul-1994-98.txt,1)
// (/statistics/1995/Jul/Jul95_request.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/statistics/1995/Jul/Jul95_byte.gif,1)
// (/pub/winvn/readme.txt,1)
// (/statistics/1995/Jul/Jul95_request.gif,1)
// (/statistics/1995/Jul/Aug95.html,1)
// (/statistics/1995/Jul/Jul95_byte.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/statistics/1995/Jul/Jul95_request.gif,1)
// (/statistics/1995/Jul/Jul95_byte.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/shuttle/missions/sts70/images/ksc-95ec-1059.jpg,1)
// (/www,1)
// (/office/pao/newsroom/today.html,1)
// (/shuttle/technology/images/apu_mods-small.gif,1)
// (/theta.com/goodman/,1)
// (/shuttle/technology/images/apu_mods-small.gif,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/shuttle/missions/sts-79/mission-sts-79.html,1)
// (/history/apollo/apollo-13/html,1)
// (/shuttle/missions/sts-81/mission-sts-81.html,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/shuttle/countdown/count69.gif,1)
// (/pub,1)
// (/elv/DELTA/uncons.htm,1)
// (/shuttle/missions/html,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/msfc/astro_home.htmll,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/pub/win3/winvn/,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/history/apollo/apollo-13-info.html,1)
// (/history/pg24.htm,1)
// (/history/apollo/apollo-13-info.html,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/history/apollo/apollo-13-info.html,1)
// (/pub/winvn/readme.txt,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo-13/apollo-13.html,1)
// (/images/crawlerway-logo.gif,1)
// (/news/sci.space.shuttle/archive/sci-space-shuttle-15-mar-1995-00.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/elv/DELTA/uncons.htm,1)
// (/images/crawlerway.gif,1)
// (/shuttle/missions/technology/sts-newsref/stsref-toc.html,1)
// (/images/crawlerway.gif,1)
// (/shuttle/missions/sts-42/mission-sts-52.html,1)
// (/images/crawlerway-logo.gif,1)
// (/shuttle/missions/sts-1/sts-1-mission.html,1)
// (/elv/new01.gif>,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/msfc/astro_home.htmll,1)
// (/payloads/systems.html,1)
// (/pub/winvn/readme.txt,1)
// (/persons/astronauts/q-to-t/TrulyRH.txt,1)
// (/pub/winvn/release.txt,1)
// (/elv/new01.gif>,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/history/apollo/sa-7/sa-7-patch-small.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/history/apollo/sa-7/sa-7-patch-small.gif,1)
// (/history/apollo.html,1)
// (/history/apollo/sa-7/images/,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/sa-7/sa-7-patch-small.gif,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/sa-7/docs/,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/sa-7/sa-7-patch-small.gif,1)
// (/ico,1)
// (/history/apollo/sa-7/news/,1)
// (/ksc.html.,1)
// (/history/apollo/sa-7/sa-7-patch-small.gif,1)
// (/ksc.html.,1)
// (/shuttle/missions/sts73.html,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/payloads/systems.html,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/htbin/,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/nasa/Cool.gif,1)
// (/history/apollo/pad-abort-test-1/images/,1)
// (/magazine/p08aug/08pet09.gif,1)
// (/history/apollo/pad-abort-test-1/sounds/,1)
// (/magazine/p08aug/08pet10.gif,1)
// (/history/apollo/pad-abort-test-1/images/,1)
// (/shuttle/technology/sts-newsref/ftp.merit.edu/maps/,1)
// (/history/apollo/pad-abort-test-2/pad-abort-test-2-patch-small.gif,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/pad-abort-test-2/images/,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/pub/winvn/win3,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/a-001/images/,1)
// (/KSC.html,1)
// (/history/apollo/sa-9/sa-9-patch-small.gif,1)
// (/pub/winvn/win3,1)
// (/history/apollo/sa-9/images/,1)
// (/pub/winvn/win3/,1)
// (/shuttle/missions/technology/sts-newsref/stsref-toc.html,1)
// (/pub/winvn/win3,1)
// (/ksc%20html,1)
// (/pub/winvn/readme.txt,1)
// (/ksc%20html,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/SDG/Experimental/demoweb/return.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/images/crawlerway-logo.gif,1)
// (/shuttle/technology/sts-newsref/sts-mes.html,1)
// (/images/lf-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/nasa/Images/nasalogo-tiny.gif,1)
// (/robots.txt,1)
// (/software/winvn/winvn.html.,1)
// (/shuttle/missions/missions.htmlUhttp://www.nasm.edu/,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-759/,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-766,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/history/apollo/apollo/13,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/apollo/13,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-70/sts-70,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-70/sts-70-press-kit.html,1)
// (/pub/winvn/readme.txt,1)
// (/winvn.html,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/winvn.html,1)
// (/pub/winvn/readme.txt,1)
// (/unitedmedia.com/comics/dilbert,1)
// (/histoty/apollo/aplool-13/apollo-13.html,1)
// (/shuttle/missions/sts-71/images/KSC-95EC-0916.txt,1)
// (/history/apollo/aplool-13/apollo-13.html,1)
// (/shuttle/news/sci.space.news/50,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/missions/sts-84/mission-sts-84.html,1)
// (/ksc-html,1)
// (/shuttle/missions/sts-71/images/KSC-95EC-0916.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/ksc_htm/,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/ksc_htm/,1)
// (/pub/winvn/readme.txt,1)
// (/ksc_htm/,1)
// (/pub/winvn/release.txt,1)
// (/ksc_htm/,1)
// (/pub/winvn/readme.txt,1)
// (/ksc_htm/,1)
// (/pub/winvn/release.txt,1)
// (/ksc-htm/,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/apollo15.html,1)
// (/SHUTTLE/MISSIONS/MISSIONS.HTML,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/SHUTTLE/MISSIONS,1)
// (/history/apollo/apollo-13/sound,1)
// (/SHUTTLE,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/apolla-13/apollo-13.html,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/shuttle/missions/sts-77/sts-77-press-kit.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/crawlerway.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/images/lf-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/lf.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/lf-logo.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/apollo-13-info.html,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/robots.txt,1)
// (/msfc/visitor.html,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/pub,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/pub,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/pub.win3.winvn,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/shuttle/resources/orbiters/atlantis.gif,1)
// (/history/apollo/sa-1/images/,1)
// (/ksc.htm,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/SDG/Experimental/demoweb/return.gif,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/images/spaceport-logo.gif,1)
// (/history/apollo/a-001/movies/,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/images/lf-logo.gif,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/images/lf-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/people/nasa-cm/jmd.html,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/procurement/expo95.htm,1)
// (/shuttle/missions/sts-73.html,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/persons/astronauts/thagar.html,1)
// (/cgi-bin/WebQuery,1)
// (/elv/DELTA/uncons.htm,1)
// (/cgi-bin/WebQuery,1)
// (/pub/winvin/docs/html,1)
// (/cgi-bin/WebQuery,1)
// (/pub/winvin/docs/html,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/pub/winvn/docs/html,1)
// (/images/crawlerway-logo.gif,1)
// (/pub,1)
// (/shuttle/technology/sts-newsref/sts-av.html#sts-dps,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/ksc.htlm,1)
// (/shuttle/countdow,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/statistics/1995/Aug/Aug95_request.gif,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/statistics/1995/Aug/Aug95_byte.gif,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/statistics/1995/Aug/Aug95_request.gif,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/statistics/1995/Aug/Aug95_byte.gif,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/ic,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/pad-abort-test-1/sounds/,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/history.html,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/skylab/skylab-3.jpg,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/release.txt,1)
// (/history/skylab/skylab-3.jpg,1)
// (/shuttle/missions/technology/sts-newsref/stsref-toc.html,1)
// (/history/skylab/skylab-3.gif,1)
// (/programs/indcan/csa.html,1)
// (/history/skylab/skylab-3.jpg,1)
// (/shuttle/missions/sts-80/mission-sts-80.html,1)
// (/history/apollo/pad-abort-test-1/images/,1)
// (/software/winvn/winvn.html>WinVN</a>,,1)
// (/history/apollo/pad-abort-test-1/sounds/,1)
// (/images/astp-logo.gif,1)
// (/history/apollo/pad-abort-test-1/movies/,1)
// (/images/crawlerway-logo.gif,1)
// (/://spacelink.msfc.nasa.gov,1)
// (/images/lps-logo.gif,1)
// (/history/apollo/a-001/images/,1)
// (/images/slf-logo.opf,1)
// (/history/apollo/apollo/apollo-13.html,1)
// (/shuttle/resources/orbiters/mpta-098-logo.gif,1)
// (/software/winvn/winvn.html.,1)
// (/shuttle/resources/orbiters/orbiter-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shusts-newsref/stsref-toc.htmlttle/technology/,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/technology/sts-newsref/stsref-toc.htmlttle/technology/,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/technology/sts-newsref/sts-newsref/stsref-toc.html,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/%3A//spacelink.msfc.nasa.gov,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/mdss/ped/acs/MDSS.html,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/apollo-13.html,1)
// (/elv/DELTA/uncons.htm,1)
// (/shuttle/missions/sts-67/images/k95p0391.gif,1)
// (/shuttle/missions/sts-67/images/k95p0381.gif,1)
// (/shuttle/missions/sts-67/images/k95p0395.gif,1)
// (/shuttle/missions/sts-67/images/k95p0391.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-71/images/KSC-95EC-0916.txt,1)
// (/yahoo.com,1)
// (/icons/blank,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/elv/DELTA/uncons.htm,1)
// (/delta.com,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/history/apollo/icons/data.gif,1)
// (/elv/DELTA/uncons.htm,1)
// (/history/apollo/icons/host.gif,1)
// (/shuttle/missions/technology/sts-newsref/stsref-toc.html,1)
// (/pub/winvn/readme.txt,1)
// (/icons/im,1)
// (/pub/winvn/release.txt,1)
// (/pub/win3/winvn,1)
// (/shuttle/missions/missions.hmtl,1)
// (/icons/im,1)
// (/shuttle/images/,1)
// (/icons/im,1)
// (/pub/winvn/readme.txt,1)
// (/software/winvn.winvn.html,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/apollo-08/apollo-08-info.html,1)
// (/pub/winvn/release.txt,1)
// (/elv/DELTA/uncons.htm,1)
// (/pub/winvn/readme.txt,1)
// (/robots.txt,1)
// (/shuttle/missions/sts-6/mission-sts-6.ht,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/release.txt,1)
// (/images/crawlerway-logo.gif,1)
// (/pub/winvn/readme.txt,1)
// (/elv/DELTA/uncons.htm,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-85/mission-sts-85.html,1)
// (/shuttle/countdowncompuserve.com,1)
// (/shuttle/missions/sts-86/mission-sts-86.html,1)
// (/robots.txt,1)
// (/shuttle/missions/sts-80/mission-sts-80.html,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/mdss/ped/acs/MDSS.html,1)
// (/pub/winvn/readme.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/payloads/systems.html,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/countdo/,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/pub/winvn/readme.txt,1)
// (/history/gemini/gemini-12.html,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/history.history.html,1)
// (/history.history.html,1)
// (/history/apollo/apollo-13/apollo-13.html.,1)
// (/shuttle/missions/51-L/mission-51-1.html,1)
// (/history/apollo/sa-1/sa-1-patch-small.gif,1)
// (/news/sci.space.shuttle/archive/sci-space-shuttle-28-jul-1994-98.txt,1)
// (/history/apollo/sa-3/sa-3-patch-small.gif,1)
// (/news/sci.space.shuttle/archive/sci-space-shuttle-27-jan-1995-08.txt,1)
// (/history/apollo/sa-4/sa-4-patch-small.gif,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/sa-4/sa-4-patch-small.gif,1)
// (/images/lf-logo.gif,1)
// (/history/apollo/sa-8/movies/,1)
// (/images/lf-logo.gif,1)
// (/history/apollo/sa-8/news/,1)
// (/elv/DELTA/uncons.htm,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/pad-abort-test-1/docs/,1)
// (/facilities/alt.sex.pictures.female,1)
// (/shuttle/missions/51-L/mission-51-l.html,1)
// (/shuttle/missions/51-L,1)
// (/elv/DELTA/uncons.htm,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/history/apollo/a-001/a-001.gif,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/msfc/astro_home.htmll,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/release.txt,1)
// (/resources/orbiters/enterprise.html,1)
// (/facilities/m/p.html,1)
// (/shuttle/missions/technology/sts-newsref/stsref-toc.html,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/shuttle/missions/51-L/mission-51.1.html,1)
// (/shuttle/missions/51-L,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/icons/image.xb,1)
// (/icons/image.xb,1)
// (/shuttle/technology/sts-newsref/srb.html#srb,1)
// (/icons/image.xb,1)
// (/icons/image.xb,1)
// (/icons/image.xb,1)
// (/shuttle/technology/sts-newsref/sts_asm.html#srb_mod_nozzle,1)
// (/missions,1)
// (/missions,1)
// (/missions/51-l,1)
// (/missions,1)
// (/missions,1)
// (/missions,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/msfc/astro_home.htmll,1)
// (/elv/DELTA/uncons.htm,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/elv/DELTA/uncons.htm,1)
// (/elv/elvpage.htm#VIDPICS,1)
// (/elv/elvpage.htm#VIDPICS,1)
// (/elv/SCOUT/elvhead2.gif,1)
// (/NASA_homepage.html,1)
// (/nasa/nasa_hottopics.html,1)
// (/calendar/,1)
// (/calendar/,1)
// (/calendar/,1)
// (/home/internet-search.html,1)
// (/home/internet-search.html,1)
// (/home/internet-search.html,1)
// (/home/internet-search.html,1)
// (/home/internet-search.html,1)
// (/home/internet-search.html,1)
// (/home/internet-search.html,1)
// (/home/internet-search.html,1)
// (/ads/images/isn_ad.gif,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn,1)
// (/users,1)
// (/persons/astronauts/thagar.html,1)
// (/msfc/Astro_home.html,1)
// (/ksc.home,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/elv/new01.gif>,1)
// (/elv/new01.gif>,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/sts-68/ksc-upclose.gif,1)
// (/shuttle/technology/sts-newsre/stsref-toc.html,1)
// (/harris,1)
// (/SDG/Experimental/demoweb/return.gif,1)
// (/SDG/Experimental/demoweb/return.gif,1)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,1)
// (/history/apollo/pad-abort-test-2/pad-abort-test-2-patch-small.gif,1)
// (/history/apollo/pad-abort-test-2/sounds/,1)
// (/history/apollo/pad-abort-test-2/pad-abort-test-2-patch-small.gif,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/history/apollo/a-001/news/,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/shuttle/missions/mission.html,1)
// (/history/apollo/images/little-joe.jpg,1)
// (/shuttle/resources/orbiters/challenger.gif,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/resources/orbiters/discovery.gif,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/history/apollo/a-001/images/,1)
// (/history/apollo/a-001/a-001-patch-small.gif,1)
// (/pub/winvn/release.txt,1)
// (/pub/winvn/readme.txt,1)
// (/history/apollo/apollo-13/apollo13.html,1)
// (/software/winvn/winvn.html.,1)
// (/history/apollo/apollo-13/apollo13.html,1)
// (/history/apollo/apollo-13/apollo13.html,1)
// (/history/apollo/apollo-13/apollo13.html,1)
// (/history/apollo/apollo-13/apollo13.html,1)
// (/robots.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/readme.txt,1)
// (/pub/winvn/release.txt,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/shuttle/missions/STS-69/mission-STS-69.html,1)
// (/pub/winvn/release.txt,1)
// (/history/apollo/images/little-joe.jpg,1)

// %% [markdown]
// ### Sample Analyses on the Web Server Log File
// Let's compute some statistics about the sizes of content being returned by the web server. In particular, we'd like to know what are the average, minimum, and maximum content sizes. We can compute the statistics by applying a `map` to the `accessLogs` RDD. The given function to the `map` should extract the `contentSize` field from the RDD. The `map` produces a new RDD, called `contentSizes`, containing only the `contentSizes`. To compute the minimum and maximum statistics, we can use `min()` and `max()` functions on the new RDD. We can compute the average statistic by using the `reduce` function with a function that sums the two inputs, which represent two elements from the new RDD that are being reduced together. The result of the `reduce()` is the total content size from the log and it is to be divided by the number of requests as determined using the `count()` function on the new RDD. As the result of executing the following box, you should get the below result:
// ```
// Content Size Avg: 17531, Min: 0, Max: 3421948
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code
// Calculate statistics based on the content size.
val contentSizes = accessLogs.map((x => x.contentSize)).cache()
println("Content Size Avg: " + contentSizes.reduce(_ + _) / contentSizes.count + ", Min: " + contentSizes.min() + ", Max: " + contentSizes.max())
// Out:
// Content Size Avg: 17531, Min: 0, Max: 3421948
// contentSizes = MapPartitionsRDD[90] at map at <console>:35
// MapPartitionsRDD[90] at map at <console>:35

// %% [markdown]
// Next, lets look at the "response codes" that appear in the log. As with the content size analysis, first we create a new RDD that contains the `responseCode` field from the `accessLogs` RDD. The difference here is that we will use a *pair tuple* instead of just the field itself (i.e., (response code, 1)). Using a pair tuple consisting of the response code and 1 will let us count the number of of records with a particular response code. Using the new RDD `responseCodes`, we perform a `reduceByKey` function that applys a given function to each element, pairwise with the same key. Then, we cache the resulting RDD and create a list by using the `take` function. Once you run the code below, you should receive the following results:
// ```
// Found 7 response codes
// Response Code Counts: (404,6185) (200,940847) (304,79824) (500,2) (501,17) (302,16244) (403,58)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

// extract the response code for each record and make pair of (response code, 1)
val responseCodes = accessLogs.map(x => (x.responseCode, 1))

// count the number of records for each key
val responseCodesCount = responseCodes.reduceByKey((x,y) => x + y, 1).cache()

// take the first 100 records
val responseCodesCountList = responseCodesCount.take(100)

println("Found " + responseCodesCountList.length + " response codes")
print("Response Code Counts: ")
responseCodesCountList.foreach(x => print(x + " "))
// Out:
// Found 7 response codes
// Response Code Counts: (404,6185) (403,58) (200,940847) (501,17) (302,16244) (304,79824) (500,2)
// responseCodes = MapPartitionsRDD[91] at map at <console>:38
// responseCodesCount = ShuffledRDD[92] at reduceByKey at <console>:41
// responseCodesCountList = Array((404,6185), (403,58), (200,940847), (501,17), (302,16244), (304,79824), (500,2))
// [(404,6185), (403,58), (200,940847), (501,17), (302,16244), (304,79824), (500,2)]

// %% [markdown]
// Let's look at "hosts" that have accessed the server multiple times (e.g., more than 10 times). First we create a new RDD to keep the `host` field from the `accessLogs` RDD using a pair tuple consisting of the host and 1 (i.e., (host, 1)), which will let us count how many records were created by a particular host's request. Using the new RDD, we perform a `reduceByKey` function with a given function to add the two values. We then filter the result based on the count of accesses by each host (the second element of each pair) being greater than 10. Next, we extract the host name by performing a `map` to return the first element of each pair. Finally, we extract 20 elements from the resulting RDD. The result should be as below:
// ```
// Any 20 hosts that have accessed more then 10 times:
// ix-aug-ga1-13.ix.netcom.com
// n1043347.ksc.nasa.gov
// d02.as1.nisiq.net
// 192.112.22.82
// anx3p4.trib.com
// 198.215.127.2
// 198.77.113.34
// crc182.cac.washington.edu
// telford-107.salford.ac.uk
// universe6.barint.on.ca
// gatekeeper.homecare.com
// 157.208.11.7
// unknown.edsa.co.za
// onyx.southwind.net
// ppp-hck-2-12.ios.com
// ix-lv5-04.ix.netcom.com
// f-umbc7.umbc.edu
// cs006p09.nam.micron.net
// dd22-025.compuserve.com
// hak-lin-kim.utm.edu
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

// extract the host field for each record and make pair of (host, 1)
val hosts = accessLogs.map(x => (x.host, 1))

// count the number of records for each key
val hostSum = hosts.reduceByKey((x,y) => x + y, 1)

// keep the records with the count greater than 10
val hostMoreThan10 = hostSum.filter(x => x._2 > 10)

// take the first ??100?? records
val hostsPick20 = hostMoreThan10.map(x => x._1).take(100)

println("Any 20 hosts that have accessed more then 10 times: ")
hostsPick20.take(20).foreach(println)
// Out:
// Any 20 hosts that have accessed more then 10 times:
// suntan.eng.usf.edu
// jcday.nccts.drenet.dnd.ca
// slip-3-3.shore.net
// beaux-gate.atwc.teradyne.com
// 198.77.113.34
// s9.its.bldrdoc.gov
// gateway.epoch.com
// forsythe-console.stanford.edu
// 139.169.151.12
// slip2-3.mountain.net
// 199.29.144.224
// slip3.nilenet.com
// 144.30.126.186
// f-umbc7.umbc.edu
// netcom21.netcom.com
// 204.180.4.123
// dd22-025.compuserve.com
// eul64.metronet.com
// 160.129.21.88
// ppp64138.chch.planet.org.nz
// hosts = MapPartitionsRDD[93] at map at <console>:39
// hostSum = ShuffledRDD[94] at reduceByKey at <console>:42
// hostMoreThan10 = MapPartitionsRDD[95] at filter at <console>:45
// hostsPick20 = Array(suntan.eng.usf.edu, jcday.nccts.drenet.dnd.ca, slip-3-3.shore.net, beaux-gate.atwc.teradyne.com, 198.77.113.34, s9.its.bldrdoc.gov, gateway.epoch.com, forsythe-console.stanford.edu, 139.169.151.12, slip2-3.mountain.net, 199.29.144.224, slip3.nilenet.com, 144.30.126.186, f-umbc7.umbc.edu, netcom21.netcom.com, 204.180.4.123, dd22-025.compuserve.com, eul64.metronet.com, 160.129.21.88, ppp64138.chch.planet.org.nz, 204.215.226.69, bos1d.delphi.com, cdbmac.pgh.wec.com...
// [suntan.eng.usf.edu, jcday.nccts.drenet.dnd.ca, slip-3-3.shore.net, beaux-gate.atwc.teradyne.com, 198.77.113.34, s9.its.bldrdoc.gov, gateway.epoch.com, forsythe-console.stanford.edu, 139.169.151.12, slip2-3.mountain.net, 199.29.144.224, slip3.nilenet.com, 144.30.126.186, f-umbc7.umbc.edu, netcom21.netcom.com, 204.180.4.123, dd22-025.compuserve.com, eul64.metronet.com, 160.129.21.88, ppp64138.chch.planet.org.nz, 204.215.226.69, bos1d.delphi.com, cdbmac.pgh.wec.com, enigma.synergy.net, dugong.ksc.nasa.gov, 134.131.38.70, 131.181.2.5, kinopravda.net4.io.org, 192.234.8.34, metiris.gcn.uoknor.edu, netport-6.iu.net, epi.kentlaw.edu, 150.210.176.77, jpnz.slip.waikato.ac.nz, jsc-b32-mac164.jsc.nasa.gov, tsn1.agt.gmeds.com, gatekeeper.hcc.com, 163.205.2.45, boldlygo.mobility.com, 204.50.15.47, a01.nationalnet.com, 192.115.161.52, 133.35.136.6, nelsons.tiac.net, isdn7-126.dnai.com, igw.fmc.com, sparx.astro.yale.edu, pma33.gfms.bt.co.uk, 192.212.4.113, 163.206.207.5, dnet032.sat.texas.net, dialup794.washington.mci.net, 129.12.43.20, stud5mac.csc.edu, ad12-009.compuserve.com, welker.slip.netcom.com, ami2000.hei.co.kr, ix-prv1-25.ix.netcom.com, port014-33-yow.sonetis.com, generic.augustana.edu, cust53.max1.orlando.fl.ms.uu.net, n870563.ksc.nasa.gov, xyplex4-1-20.ucs.indiana.edu, ccc018.canuck.com, 128.217.62.80, yeo.jsc.nasa.gov, slip-13-7.ots.utexas.edu, verdi.nmsu.edu, dialin-35.wustl.edu, 199.185.209.15, 128.250.94.30, ppp060-stdkn2.ulaval.ca, pm6a3.sover.net, 133.43.96.45, osaka121.infosphere.or.jp, ct-pc2.chem.uva.nl, line44.megatoon.com, atleng123.globalvillag.com, purenrg.charm.net, pm1-20.conline.com, fredremote1.gwcc.com, ttyv8.tyrell.net, 204.134.97.34, 205.161.217.221, ix-day-oh1-05.ix.netcom.com, 205.184.7.35, drjo011a044.embratel.net.br, miron.hip.cam.org, arnetpc-195.arn.net, ppp016.st.rim.or.jp, imed2024.med.uth.tmc.edu, 140.229.38.119, ix-sac10-24.ix.netcom.com, triskila.fmi.fi, hutt.dev.wholesale.nbnz.co.nz, basset.cisco.com, sks.enss74.t3.ans.net, 200.14.117.58, 198.79.88.216, ts900-1311.singnet.com.sg]

// %% [markdown]
// For the final example, we'll look at the top endpoints (URIs) in the log. To determine them, we first create a new RDD to extract the `endpoint` field from the `accessLogs` RDD using a pair tuple consisting of the endpoint and 1 (i.e., (endpoint, 1)), which will let us count how many records were created by a particular host's request. Using the new RDD, we perform a `reduceByKey` to add the two values. We then extract the top 10 endpoints by performing a `takeOrdered` with a value of 10 and a function that multiplies the count (the second element of each pair) by -1 to create a sorted list with the top endpoints at the bottom. Here is the result:
// ```
// Top ten endpoints:
// (/images/NASA-logosmall.gif,59737)
// (/images/KSC-logosmall.gif,50452)
// (/images/MOSAIC-logosmall.gif,43890)
// (/images/USA-logosmall.gif,43664)
// (/images/WORLD-logosmall.gif,43277)
// (/images/ksclogo-medium.gif,41336)
// (/ksc.html,28582)
// (/history/apollo/images/apollo-logo1.gif,26778)
// (/images/launch-logo.gif,24755)
// (/,20292)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

// extract the endpoint for each record and make pair of (endpoiint, 1)
val endpoints = accessLogs.map(x => (x.endpoint, 1))

// count the number of records for each key
val endpointCounts = endpoints.reduceByKey((x, y) => x + y, 1 )

// extract the top 10 
val topEndpoints = endpointCounts.takeOrdered(10)(Ordering.by(_._2 *(-1)))

println("Top ten endpoints: ")
topEndpoints.foreach(println)
// Out:
// Top ten endpoints:
// (/images/NASA-logosmall.gif,59737)
// (/images/KSC-logosmall.gif,50452)
// (/images/MOSAIC-logosmall.gif,43890)
// (/images/USA-logosmall.gif,43664)
// (/images/WORLD-logosmall.gif,43277)
// (/images/ksclogo-medium.gif,41336)
// (/ksc.html,28582)
// (/history/apollo/images/apollo-logo1.gif,26778)
// (/images/launch-logo.gif,24755)
// (/,20292)
// endpoints = MapPartitionsRDD[97] at map at <console>:38
// endpointCounts = ShuffledRDD[98] at reduceByKey at <console>:41
// topEndpoints = Array((/images/NASA-logosmall.gif,59737), (/images/KSC-logosmall.gif,50452), (/images/MOSAIC-logosmall.gif,43890), (/images/USA-logosmall.gif,43664), (/images/WORLD-logosmall.gif,43277), (/images/ksclogo-medium.gif,41336), (/ksc.html,28582), (/history/apollo/images/apollo-logo1.gif,26778), (/images/launch-logo.gif,24755), (/,20292))
// [(/images/NASA-logosmall.gif,59737), (/images/KSC-logosmall.gif,50452), (/images/MOSAIC-logosmall.gif,43890), (/images/USA-logosmall.gif,43664), (/images/WORLD-logosmall.gif,43277), (/images/ksclogo-medium.gif,41336), (/ksc.html,28582), (/history/apollo/images/apollo-logo1.gif,26778), (/images/launch-logo.gif,24755), (/,20292)]

// %% [markdown]
// ### Analyzing Web Server Log File
// What are the top ten endpoints which did not have return code 200? Create a sorted list containing top ten endpoints and the number of times that they were accessed with non-200 return code. Think about the steps that you need to perform to determine which endpoints did not have a 200 return code, how you will uniquely count those endpoints, and sort the list. You should receive the following result:
// ```
// Top ten failed URLs:
// (/images/NASA-logosmall.gif,8761)
// (/images/KSC-logosmall.gif,7236)
// (/images/MOSAIC-logosmall.gif,5197)
// (/images/USA-logosmall.gif,5157)
// (/images/WORLD-logosmall.gif,5020)
// (/images/ksclogo-medium.gif,4728)
// (/history/apollo/images/apollo-logo1.gif,2907)
// (/images/launch-logo.gif,2811)
// (/,2199)
// (/images/ksclogosmall.gif,1622)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

// keep the logs with error code not 200
val not200 = accessLogs.filter(x => x.responseCode != 200)

// make a pair of (x, 1)
val endpointCountPairTuple = not200.map(x => (x.endpoint, 1))

// count the number of records for each key x
val endpointSum = endpointCountPairTuple.reduceByKey((x, y) => x + y, 1)

// take the top 10
val topTenErrURLs = endpointSum.takeOrdered(10)(Ordering.by(_._2 *(-1)))

println("Top ten failed URLs: ")
topTenErrURLs.foreach(println)
// Out:
// Top ten failed URLs:
// (/images/NASA-logosmall.gif,8761)
// (/images/KSC-logosmall.gif,7236)
// (/images/MOSAIC-logosmall.gif,5197)
// (/images/USA-logosmall.gif,5157)
// (/images/WORLD-logosmall.gif,5020)
// (/images/ksclogo-medium.gif,4728)
// (/history/apollo/images/apollo-logo1.gif,2907)
// (/images/launch-logo.gif,2811)
// (/,2199)
// (/images/ksclogosmall.gif,1622)
// not200 = MapPartitionsRDD[100] at filter at <console>:39
// endpointCountPairTuple = MapPartitionsRDD[101] at map at <console>:42
// endpointSum = ShuffledRDD[102] at reduceByKey at <console>:45
// topTenErrURLs = Array((/images/NASA-logosmall.gif,8761), (/images/KSC-logosmall.gif,7236), (/images/MOSAIC-logosmall.gif,5197), (/images/USA-logosmall.gif,5157), (/images/WORLD-logosmall.gif,5020), (/images/ksclogo-medium.gif,4728), (/history/apollo/images/apollo-logo1.gif,2907), (/images/launch-logo.gif,2811), (/,2199), (/images/ksclogosmall.gif,1622))
// [(/images/NASA-logosmall.gif,8761), (/images/KSC-logosmall.gif,7236), (/images/MOSAIC-logosmall.gif,5197), (/images/USA-logosmall.gif,5157), (/images/WORLD-logosmall.gif,5020), (/images/ksclogo-medium.gif,4728), (/history/apollo/images/apollo-logo1.gif,2907), (/images/launch-logo.gif,2811), (/,2199), (/images/ksclogosmall.gif,1622)]

// %% [markdown]
// Let's count the number of unique hosts in the entire log. Think about the steps that you need to perform to count the number of different hosts in the log. The result should be as below:
// ```
// Unique hosts: 54507
//
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

// extract the host field for each record
val hosts = accessLogs.map(x => x.host)

// keep the uniqe hosts
val uniqueHosts = hosts.distinct

// count them
val uniqueHostCount = uniqueHosts.count()

println("Unique hosts: " + uniqueHostCount)
// Out:
// Unique hosts: 54507
// hosts = MapPartitionsRDD[104] at map at <console>:38
// uniqueHosts = MapPartitionsRDD[107] at distinct at <console>:41
// uniqueHostCount = 54507
// 54507

// %% [markdown]
// For an advanced exercise, let's determine the number of unique hosts in the entire log on a day-by-day basis. This computation will give us counts of the number of unique daily hosts. We'd like a list sorted by increasing day of the month, which includes the day of the month and the associated number of unique hosts for that day. Make sure you cache the resulting RDD `dailyHosts`, so that we can reuse it in the next exercise. Think about the steps that you need to perform to count the number of different hosts that make requests *each* day. Since the log only covers a single month, you can ignore the month. Here is the output you should receive:
// ```
// Unique hosts per day:
// (1,2582)
// (3,3222)
// (4,4190)
// (5,2502)
// (6,2537)
// (7,4106)
// (8,4406)
// (9,4317)
// (10,4523)
// (11,4346)
// (12,2864)
// (13,2650)
// (14,4454)
// (15,4214)
// (16,4340)
// (17,4385)
// (18,4168)
// (19,2550)
// (20,2560)
// (21,4134)
// (22,4456)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

// make pairs of (day, host)
val dayToHostPairTuple = accessLogs.map(x => (x.dateTime.day, x.host))

// group by day
val dayGroupedHosts = dayToHostPairTuple
                        .map{case (day, host) => (day, Set(host))}
                        .reduceByKey(_ ++ _)

// make pairs of (day, number of host in that day)
val dayHostCount = dayGroupedHosts.map{case (day, hostSet) => (day, hostSet.size)}

// sort by day
val dailyHosts = dayHostCount.sortByKey(ascending=true).cache

// return the records as a list
val dailyHostsList = dailyHosts.take(30)

// println("Unique hosts per day: ")
dailyHostsList.foreach(println)
// Out:
// (1,2582)
// (3,3222)
// (4,4190)
// (5,2502)
// (6,2537)
// (7,4106)
// (8,4406)
// (9,4317)
// (10,4523)
// (11,4346)
// (12,2864)
// (13,2650)
// (14,4454)
// (15,4214)
// (16,4340)
// (17,4385)
// (18,4168)
// (19,2550)
// (20,2560)
// (21,4134)
// (22,4456)
// dayToHostPairTuple = MapPartitionsRDD[523] at map at <console>:40
// dayGroupedHosts = ShuffledRDD[525] at reduceByKey at <console>:45
// dayHostCount = MapPartitionsRDD[526] at map at <console>:48
// dailyHosts = ShuffledRDD[529] at sortByKey at <console>:51
// dailyHostsList = Array((1,2582), (3,3222), (4,4190), (5,2502), (6,2537), (7,4106), (8,4406), (9,4317), (10,4523), (11,4346), (12,2864), (13,2650), (14,4454), (15,4214), (16,4340), (17,4385), (18,4168), (19,2550), (20,2560), (21,4134), (22,4456))
// [(1,2582), (3,3222), (4,4190), (5,2502), (6,2537), (7,4106), (8,4406), (9,4317), (10,4523), (11,4346), (12,2864), (13,2650), (14,4454), (15,4214), (16,4340), (17,4385), (18,4168), (19,2550), (20,2560), (21,4134), (22,4456)]

// %% [markdown]
// Next, let's determine the average number of requests on a day-by-day basis. We'd like a list by increasing day of the month and the associated average number of requests per host for that day. Make sure you cache the resulting RDD `avgDailyReqPerHost` so that we can reuse it in the next exercise. To compute the average number of requests per host, get the total number of request across all hosts and divide that by the number of unique hosts. Since the log only covers a single month, you can skip checking for the month. Also to keep it simple, when calculating the approximate average use the integer value. The result should be as below:
// ```
// Average number of daily requests per Hosts is:
// (1,13)
// (3,12)
// (4,14)
// (5,12)
// (6,12)
// (7,13)
// (8,13)
// (9,14)
// (10,13)
// (11,14)
// (12,13)
// (13,13)
// (14,13)
// (15,13)
// (16,13)
// (17,13)
// (18,13)
// (19,12)
// (20,12)
// (21,13)
// (22,12)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code


// make pairs of (day, host)
val dayAndHostTuple = accessLogs.map(x => (x.dateTime.day, x.host))

// group by day
val groupedByDay = dayAndHostTuple
                        .map{case (day, host) => (day, Set(host))}
                        .reduceByKey(_ ++ _).map{case (day, hostSet) => (day, hostSet.size)}

val groupedByDayTotal = dayAndHostTuple
                        .map{case (day, host) => (day, 1)}
                        .reduceByKey((x,y) => x + y)

// // calculate the average request per day
val avgDailyReqPerHost = sortedByDay.join(groupedByDayTotal).map{case (day, (u, t)) => (day, t/u)}.sortByKey(ascending=true)

// // return the records as a list
val avgDailyReqPerHostList = avgDailyReqPerHost.take(30)

println("Average number of daily requests per Hosts is: ")
avgDailyReqPerHostList.foreach(println)
// Out:
// Average number of daily requests per Hosts is:
// (1,13)
// (3,12)
// (4,14)
// (5,12)
// (6,12)
// (7,13)
// (8,13)
// (9,14)
// (10,13)
// (11,14)
// (12,13)
// (13,13)
// (14,13)
// (15,13)
// (16,13)
// (17,13)
// (18,13)
// (19,12)
// (20,12)
// (21,13)
// (22,12)
// dayAndHostTuple = MapPartitionsRDD[509] at map at <console>:42
// groupedByDay = MapPartitionsRDD[512] at map at <console>:47
// groupedByDayTotal = ShuffledRDD[514] at reduceByKey at <console>:51
// avgDailyReqPerHost = ShuffledRDD[521] at sortByKey at <console>:54
// avgDailyReqPerHostList = Array((1,13), (3,12), (4,14), (5,12), (6,12), (7,13), (8,13), (9,14), (10,13), (11,14), (12,13), (13,13), (14,13), (15,13), (16,13), (17,13), (18,13), (19,12), (20,12), (21,13), (22,12))
// [(1,13), (3,12), (4,14), (5,12), (6,12), (7,13), (8,13), (9,14), (10,13), (11,14), (12,13), (13,13), (14,13), (15,13), (16,13), (17,13), (18,13), (19,12), (20,12), (21,13), (22,12)]

// %% [markdown]
// ### Exploring 404 Response Codes
// Let's count the 404 response codes. Create a RDD containing only log records with a 404 response code. Make sure you `cache()` the RDD `badRecords` as we will use it in the rest of this exercise. How many 404 records are in the log? Here is the result:
// ```
// Found 6185 404 URLs.
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

val badRecords = accessLogs.filter(x => x.responseCode == 404).cache()
println("Found " + badRecords.count() + " 404 URLs.")
// Out:
// Found 6185 404 URLs.
// badRecords = MapPartitionsRDD[7] at filter at <console>:33
// MapPartitionsRDD[7] at filter at <console>:33

// %% [markdown]
// Now, let's list the 404 response code records. Using the RDD containing only log records with a 404 response code that you cached in the previous part, print out a list up to 10 distinct endpoints that generate 404 errors -  no endpoint should appear more than once in your list. You should receive the follwoing output as your result:
// ```
// 404 URLS:
// /SHUTTLE/COUNTDOWN
// /shuttle/missions/sts-71/images/www.acm.uiuc.edu/rml/Gifs
// /shuttle/technology/stsnewsrof/stsref-toc.html
// /de/systems.html
// /ksc.htnl
// /~pccomp/graphics/sinsght.gif
// /PERSONS/NASA-CM.
// /shuttle/missions/sts-1/sts-1-mission.html
// /history/apollo/sa-1/sa-1-patch-small.gif
// /images/sts-63-Imax
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

val badEndpoints = badRecords.map(x => x.endpoint)
val badUniqueEndpoints = badEndpoints.distinct
val badUniqueEndpointsPick10 = badUniqueEndpoints.take(10)

println("404 URLS: ")
badUniqueEndpointsPick10.foreach(println)
// Out:
// 404 URLS:
// /SHUTTLE/COUNTDOWN
// /shuttle/missions/sts-71/images/www.acm.uiuc.edu/rml/Gifs
// /shuttle/technology/stsnewsrof/stsref-toc.html
// /de/systems.html
// /ksc.htnl
// /~pccomp/graphics/sinsght.gif
// /PERSONS/NASA-CM.
// /shuttle/missions/sts-1/sts-1-mission.html
// /history/apollo/sa-1/sa-1-patch-small.gif
// /images/sts-63-Imax
// badEndpoints = MapPartitionsRDD[8] at map at <console>:35
// badUniqueEndpoints = MapPartitionsRDD[11] at distinct at <console>:36
// badUniqueEndpointsPick10 = Array(/SHUTTLE/COUNTDOWN, /shuttle/missions/sts-71/images/www.acm.uiuc.edu/rml/Gifs, /shuttle/technology/stsnewsrof/stsref-toc.html, /de/systems.html, /ksc.htnl, /~pccomp/graphics/sinsght.gif, /PERSONS/NASA-CM., /shuttle/missions/sts-1/sts-1-mission.html, /history/apollo/sa-1/sa-1-patch-small.gif, /images/sts-63-Imax)
// [/SHUTTLE/COUNTDOWN, /shuttle/missions/sts-71/images/www.acm.uiuc.edu/rml/Gifs, /shuttle/technology/stsnewsrof/stsref-toc.html, /de/systems.html, /ksc.htnl, /~pccomp/graphics/sinsght.gif, /PERSONS/NASA-CM., /shuttle/missions/sts-1/sts-1-mission.html, /history/apollo/sa-1/sa-1-patch-small.gif, /images/sts-63-Imax]

// %% [markdown]
// Using the RDD containing only log records with a 404 response code that you cached before, print out a list of the top 10 endpoints that generate the most 404 errors. Remember, top endpoints should be in sorted order. The result would be as below:
// ```
// Top ten 404 URLs:
// (/pub/winvn/readme.txt,633)
// (/pub/winvn/release.txt,494)
// (/shuttle/missions/STS-69/mission-STS-69.html,431)
// (/images/nasa-logo.gif,319)
// (/elv/DELTA/uncons.htm,178)
// (/shuttle/missions/sts-68/ksc-upclose.gif,156)
// (/history/apollo/sa-1/sa-1-patch-small.gif,146)
// (/images/crawlerway-logo.gif,120)
// (/://spacelink.msfc.nasa.gov,117)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,100)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

val badEndpointsCountPairTuple = badRecords.map(x => (x.endpoint, 1))
val badEndpointsSum = badEndpointsCountPairTuple.reduceByKey((x,y) => x + y, 1)


// sort the records (you should implement a new object by extending the Ordering class for this part)
object ErrOrdering extends Ordering[(String, Int)] {
    def compare(a:(String, Int), b: (String, Int)) : Int = a._2.compare(b._2)
}

val badEndpointsTop10 = badEndpointsSum.takeOrdered(10)(ErrOrdering.reverse)

println("Top ten 404 URLs: ")
badEndpointsTop10.foreach(println)
// Out:
// Top ten 404 URLs:
// (/pub/winvn/readme.txt,633)
// (/pub/winvn/release.txt,494)
// (/shuttle/missions/STS-69/mission-STS-69.html,431)
// (/images/nasa-logo.gif,319)
// (/elv/DELTA/uncons.htm,178)
// (/shuttle/missions/sts-68/ksc-upclose.gif,156)
// (/history/apollo/sa-1/sa-1-patch-small.gif,146)
// (/images/crawlerway-logo.gif,120)
// (/://spacelink.msfc.nasa.gov,117)
// (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,100)
// badEndpointsCountPairTuple = MapPartitionsRDD[43] at map at <console>:40
// badEndpointsSum = ShuffledRDD[44] at reduceByKey at <console>:41
// defined object ErrOrdering
// badEndpointsTop10 = Array((/pub/winvn/readme.txt,633), (/pub/winvn/release.txt,494), (/shuttle/missions/STS-69/mission-STS-69.html,431), (/images/nasa-logo.gif,319), (/elv/DELTA/uncons.htm,178), (/shuttle/missions/sts-68/ksc-upclose.gif,156), (/history/apollo/sa-1/sa-1-patch-small.gif,146), (/images/crawlerway-logo.gif,120), (/://spacelink.msfc.nasa.gov,117), (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,100))
// [(/pub/winvn/readme.txt,633), (/pub/winvn/release.txt,494), (/shuttle/missions/STS-69/mission-STS-69.html,431), (/images/nasa-logo.gif,319), (/elv/DELTA/uncons.htm,178), (/shuttle/missions/sts-68/ksc-upclose.gif,156), (/history/apollo/sa-1/sa-1-patch-small.gif,146), (/images/crawlerway-logo.gif,120), (/://spacelink.msfc.nasa.gov,117), (/history/apollo/pad-abort-test-1/pad-abort-test-1-patch-small.gif,100)]

// %% [markdown]
// Instead of looking at the endpoints that generated 404 errors, now let's look at the hosts that encountered 404 errors. Using the RDD containing only log records with a 404 response code that you cached before, print out a list of the top 10 hosts that generate the most 404 errors. Here is the result:
// ```
// Top ten hosts that generated errors:
// (piweba3y.prodigy.com,39)
// (maz3.maz.net,39)
// (gate.barr.com,38)
// (m38-370-9.mit.edu,37)
// (ts8-1.westwood.ts.ucla.edu,37)
// (nexus.mlckew.edu.au,37)
// (204.62.245.32,33)
// (spica.sci.isas.ac.jp,27)
// (163.206.104.34,27)
// (www-d4.proxy.aol.com,26)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

val errHostsCountPairTuple = badRecords.map(x => (x.host, 1))
val errHostsSum = errHostsCountPairTuple.reduceByKey(_ + _)
val errHostsTop10 = errHostsSum.takeOrdered(10)(ErrOrdering.reverse)

println("Top ten hosts that generated errors: ")
errHostsTop10.foreach(println)
// Out:
// Top ten hosts that generated errors:
// (piweba3y.prodigy.com,39)
// (maz3.maz.net,39)
// (gate.barr.com,38)
// (nexus.mlckew.edu.au,37)
// (ts8-1.westwood.ts.ucla.edu,37)
// (m38-370-9.mit.edu,37)
// (204.62.245.32,33)
// (163.206.104.34,27)
// (spica.sci.isas.ac.jp,27)
// (www-d4.proxy.aol.com,26)
// errHostsCountPairTuple = MapPartitionsRDD[46] at map at <console>:37
// errHostsSum = ShuffledRDD[47] at reduceByKey at <console>:38
// errHostsTop10 = Array((piweba3y.prodigy.com,39), (maz3.maz.net,39), (gate.barr.com,38), (nexus.mlckew.edu.au,37), (ts8-1.westwood.ts.ucla.edu,37), (m38-370-9.mit.edu,37), (204.62.245.32,33), (163.206.104.34,27), (spica.sci.isas.ac.jp,27), (www-d4.proxy.aol.com,26))
// [(piweba3y.prodigy.com,39), (maz3.maz.net,39), (gate.barr.com,38), (nexus.mlckew.edu.au,37), (ts8-1.westwood.ts.ucla.edu,37), (m38-370-9.mit.edu,37), (204.62.245.32,33), (163.206.104.34,27), (spica.sci.isas.ac.jp,27), (www-d4.proxy.aol.com,26)]

// %% [markdown]
// Let's explore the 404 records temporally. Break down the 404 requests by day and get the daily counts sorted by day as a list. Since the log only covers a single month, you can ignore the month in your checks. Cache the `errDateSorted` at the end. The output should be as below:
// ```
// 404 errors by day:
// (1,243)
// (3,303)
// (4,346)
// (5,234)
// (6,372)
// (7,532)
// (8,381)
// (9,279)
// (10,314)
// (11,263)
// (12,195)
// (13,216)
// (14,287)
// (15,326)
// (16,258)
// (17,269)
// (18,255)
// (19,207)
// (20,312)
// (21,305)
// (22,288)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

val errDateCountPairTuple = badRecords.map(x => (x.dateTime.day, 1))
val errDateSum = errDateCountPairTuple.reduceByKey(_ + _)
val errDateSorted = errDateSum
val errByDate = errDateSorted.takeOrdered(30)
errDateSorted.cache()

println("404 errors by day: ")
errByDate.foreach(println)
// Out:
// 404 errors by day:
// (1,243)
// (3,303)
// (4,346)
// (5,234)
// (6,372)
// (7,532)
// (8,381)
// (9,279)
// (10,314)
// (11,263)
// (12,195)
// (13,216)
// (14,287)
// (15,326)
// (16,258)
// (17,269)
// (18,255)
// (19,207)
// (20,312)
// (21,305)
// (22,288)
// errDateCountPairTuple = MapPartitionsRDD[49] at map at <console>:35
// errDateSum = ShuffledRDD[50] at reduceByKey at <console>:36
// errDateSorted = ShuffledRDD[50] at reduceByKey at <console>:36
// errByDate = Array((1,243), (3,303), (4,346), (5,234), (6,372), (7,532), (8,381), (9,279), (10,314), (11,263), (12,195), (13,216), (14,287), (15,326), (16,258), (17,269), (18,255), (19,207), (20,312), (21,305), (22,288))
// [(1,243), (3,303), (4,346), (5,234), (6,372), (7,532), (8,381), (9,279), (10,314), (11,263), (12,195), (13,216), (14,287), (15,326), (16,258), (17,269), (18,255), (19,207), (20,312), (21,305), (22,288)]

// %% [markdown]
// Using the RDD `errDateSorted` you cached before, what are the top five days for 404 response codes and the corresponding counts of 404 response codes?
// ```
// Top five dates for 404 requests: (7,532) (8,381) (6,372) (4,346) (15,326)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

object DateOrdering extends Ordering[(Int, Int)] {
  def compare(x:(Int, Int), y:(Int, Int)) : Int = x._2.compare(y._2)
}

val topErrDate = errDateSorted.takeOrdered(5)(DateOrdering.reverse)

print("Top five dates for 404 requests: ")
topErrDate.foreach(x => print(x + " "))
// Out:
// Top five dates for 404 requests: (7,532) (8,381) (6,372) (4,346) (15,326)
// defined object DateOrdering
// topErrDate = Array((7,532), (8,381), (6,372), (4,346), (15,326))
// [(7,532), (8,381), (6,372), (4,346), (15,326)]

// %% [markdown]
// Using the RDD `badRecords` you cached before, and by hour of the day and in increasing order, create an RDD containing how many requests had a 404 return code for each hour of the day (midnight starts at 0).
// ```
// Top hours for 404 requests:
// (0,175)
// (1,171)
// (2,422)
// (3,272)
// (4,102)
// (5,95)
// (6,93)
// (7,122)
// (8,199)
// (9,185)
// (10,329)
// (11,263)
// (12,438)
// (13,397)
// (14,318)
// (15,347)
// (16,373)
// (17,330)
// (18,268)
// (19,269)
// (20,270)
// (21,241)
// (22,234)
// (23,272)
// ```

// %%
// TODO: Replace <FILL IN> with appropriate code

val hourCountPairTuple = badRecords.map(x => (x.dateTime.hour, 1))
val hourRecordsSum = hourCountPairTuple.reduceByKey(_ + _)
val hourRecordsSorted = hourRecordsSum.sortByKey(ascending=true)
val errHourList = hourRecordsSorted.take(24)

println("Top hours for 404 requests: ")
errHourList.foreach(println)
// Out:
// Top hours for 404 requests:
// (0,175)
// (1,171)
// (2,422)
// (3,272)
// (4,102)
// (5,95)
// (6,93)
// (7,122)
// (8,199)
// (9,185)
// (10,329)
// (11,263)
// (12,438)
// (13,397)
// (14,318)
// (15,347)
// (16,373)
// (17,330)
// (18,268)
// (19,269)
// (20,270)
// (21,241)
// (22,234)
// (23,272)
// hourCountPairTuple = MapPartitionsRDD[56] at map at <console>:42
// hourRecordsSum = ShuffledRDD[57] at reduceByKey at <console>:43
// hourRecordsSorted = ShuffledRDD[60] at sortByKey at <console>:44
// errHourList = Array((0,175), (1,171), (2,422), (3,272), (4,102), (5,95), (6,93), (7,122), (8,199), (9,185), (10,329), (11,263), (12,438), (13,397), (14,318), (15,347), (16,373), (17,330), (18,268), (19,269), (20,270), (21,241), (22,234), (23,272))
// [(0,175), (1,171), (2,422), (3,272), (4,102), (5,95), (6,93), (7,122), (8,199), (9,185), (10,329), (11,263), (12,438), (13,397), (14,318), (15,347), (16,373), (17,330), (18,268), (19,269), (20,270), (21,241), (22,234), (23,272)]
